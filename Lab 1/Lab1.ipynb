# %%
import pandas as pd

# %%
info1 = pd.read_csv('ipl1.csv')
info2 = pd.read_csv('ipl2.csv')

# %%
info1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
info2
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
pd.isnull(info1).sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
pd.isnull(info2).sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
ans2 = pd.merge(info1, info2, on = "id")

# %%
ans2
# Out:
#              id       city        date player_of_match  \
# 0        335982  Bangalore  2008-04-18     BB McCullum
# 1        335982  Bangalore  2008-04-18     BB McCullum
# 2        335982  Bangalore  2008-04-18     BB McCullum
# 3        335982  Bangalore  2008-04-18     BB McCullum
# 4        335982  Bangalore  2008-04-18     BB McCullum
# ...         ...        ...         ...             ...
# 193463  1237181      Dubai  2020-11-10        TA Boult
# 193464  1237181      Dubai  2020-11-10        TA Boult
# 193465  1237181      Dubai  2020-11-10        TA Boult
# 193466  1237181      Dubai  2020-11-10        TA Boult
# 193467  1237181      Dubai  2020-11-10        TA Boult
#
#                                       venue  neutral_venue  \
# 0                     M Chinnaswamy Stadium              0
# 1                     M Chinnaswamy Stadium              0
# 2                     M Chinnaswamy Stadium              0
# 3                     M Chinnaswamy Stadium              0
# ...

# %%
pd.isnull(ans2).sum()
# Out:
# id                       0
# city                  3139
# date                     0
# player_of_match        372
# venue                    0
# neutral_venue            0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 372
# result                 372
# result_margin         3597
# eliminator             372
# method              190260
# umpire1                  0
# umpire2                  0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# ...

# %%
ans2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193468 entries, 0 to 193467
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   city              190329 non-null  object
#  2   date              193468 non-null  object
#  3   player_of_match   193096 non-null  object
#  4   venue             193468 non-null  object
#  5   neutral_venue     193468 non-null  int64
#  6   team1             193468 non-null  object
#  7   team2             193468 non-null  object
#  8   toss_winner       193468 non-null  object
#  9   toss_decision     193468 non-null  object
#  10  winner            193096 non-null  object
#  11  result            193096 non-null  object
#  12  result_margin     189871 non-null  float64
#  13  eliminator        193096 non-null  object
#  14  method            3208 non-null    object
#  15  umpire1           193468 non-null  object
# ...

# %%
ans2['date'] = pd.to_datetime(ans2['date'])

# %%
ans2.dtypes
# Out:
# id                           int64
# city                        object
# date                datetime64[ns]
# player_of_match             object
# venue                       object
# neutral_venue                int64
# team1                       object
# team2                       object
# toss_winner                 object
# toss_decision               object
# winner                      object
# result                      object
# result_margin              float64
# eliminator                  object
# method                      object
# umpire1                     object
# umpire2                     object
# inning                       int64
# over                         int64
# ball                         int64
# batsman                     object
# non_striker                 object
# bowler                      object
# batsman_runs                 int64
# extra_runs                   int64
# total_runs                   int64
# non_boundary                 int64
# ...

# %% [markdown]
# All the columns have the correct Datatype.

# %%
index = pd.Index(range(1, 193469, 1))
ans2 = ans2.set_index(index)

# %%
ans2
# Out:
#              id       city       date player_of_match  \
# 1        335982  Bangalore 2008-04-18     BB McCullum
# 2        335982  Bangalore 2008-04-18     BB McCullum
# 3        335982  Bangalore 2008-04-18     BB McCullum
# 4        335982  Bangalore 2008-04-18     BB McCullum
# 5        335982  Bangalore 2008-04-18     BB McCullum
# ...         ...        ...        ...             ...
# 193464  1237181      Dubai 2020-11-10        TA Boult
# 193465  1237181      Dubai 2020-11-10        TA Boult
# 193466  1237181      Dubai 2020-11-10        TA Boult
# 193467  1237181      Dubai 2020-11-10        TA Boult
# 193468  1237181      Dubai 2020-11-10        TA Boult
#
#                                       venue  neutral_venue  \
# 1                     M Chinnaswamy Stadium              0
# 2                     M Chinnaswamy Stadium              0
# 3                     M Chinnaswamy Stadium              0
# 4                     M Chinnaswamy Stadium              0
# ...

# %%
import seaborn as sns

# %%
sns.boxplot(ans2['batsman_runs'])
# Out:
# /Users/saraghosalkar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batsman_runs'>

# %%
sns.boxplot(ans2['total_runs'])
# Out:
# /Users/saraghosalkar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_runs'>

# %%
info1['date'] = pd.to_datetime(info1['date'])

# %%
info1.groupby(pd.Grouper(key='date', freq='1Y')).size()
# Out:
# date
# 2008-12-31    58
# 2009-12-31    57
# 2010-12-31    60
# 2011-12-31    73
# 2012-12-31    74
# 2013-12-31    76
# 2014-12-31    60
# 2015-12-31    59
# 2016-12-31    60
# 2017-12-31    59
# 2018-12-31    60
# 2019-12-31    60
# 2020-12-31    60
# Freq: A-DEC, dtype: int64

# %%
ans2.groupby(pd.Grouper(key='date', freq='1Y'))['total_runs'].sum()
# Out:
# date
# 2008-12-31    17937
# 2009-12-31    16320
# 2010-12-31    18864
# 2011-12-31    21154
# 2012-12-31    22453
# 2013-12-31    22541
# 2014-12-31    18909
# 2015-12-31    18332
# 2016-12-31    18862
# 2017-12-31    18769
# 2018-12-31    19901
# 2019-12-31    19400
# 2020-12-31    19352
# Freq: A-DEC, Name: total_runs, dtype: int64

# %%
ans2['winner'].value_counts().nlargest(10)
# Out:
# Mumbai Indians                 28885
# Chennai Super Kings            25531
# Kolkata Knight Riders          23358
# Royal Challengers Bangalore    21240
# Kings XI Punjab                20904
# Rajasthan Royals               19370
# Delhi Daredevils               15709
# Sunrisers Hyderabad            15667
# Deccan Chargers                 7013
# Delhi Capitals                  4663
# Name: winner, dtype: int64

# %%
ans2['player_of_match'].value_counts().nlargest(10)
# Out:
# AB de Villiers    5663
# CH Gayle          5186
# RG Sharma         4412
# MS Dhoni          4130
# DA Warner         4076
# SR Watson         3807
# YK Pathan         3724
# SK Raina          3400
# G Gambhir         3107
# AM Rahane         2916
# Name: player_of_match, dtype: int64

# %%
ans2['toss_decision'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# field    60.5%
# bat      39.5%
# Name: toss_decision, dtype: object
