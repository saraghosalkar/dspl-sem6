# %%
import pandas as pd

# %%
info1 = pd.read_csv('ipl1.csv')
info2 = pd.read_csv('ipl2.csv')

# %%
info1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
info2
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
pd.isnull(info1).sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
pd.isnull(info2).sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
ans2 = pd.merge(info1, info2, on = "id")

# %%
ans2
# Out:
#              id       city        date player_of_match  \
# 0        335982  Bangalore  2008-04-18     BB McCullum
# 1        335982  Bangalore  2008-04-18     BB McCullum
# 2        335982  Bangalore  2008-04-18     BB McCullum
# 3        335982  Bangalore  2008-04-18     BB McCullum
# 4        335982  Bangalore  2008-04-18     BB McCullum
# ...         ...        ...         ...             ...
# 193463  1237181      Dubai  2020-11-10        TA Boult
# 193464  1237181      Dubai  2020-11-10        TA Boult
# 193465  1237181      Dubai  2020-11-10        TA Boult
# 193466  1237181      Dubai  2020-11-10        TA Boult
# 193467  1237181      Dubai  2020-11-10        TA Boult
#
#                                       venue  neutral_venue  \
# 0                     M Chinnaswamy Stadium              0
# 1                     M Chinnaswamy Stadium              0
# 2                     M Chinnaswamy Stadium              0
# 3                     M Chinnaswamy Stadium              0
# ...

# %%
pd.isnull(ans2).sum()
# Out:
# id                       0
# city                  3139
# date                     0
# player_of_match        372
# venue                    0
# neutral_venue            0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 372
# result                 372
# result_margin         3597
# eliminator             372
# method              190260
# umpire1                  0
# umpire2                  0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# ...

# %%
ans2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193468 entries, 0 to 193467
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   city              190329 non-null  object
#  2   date              193468 non-null  object
#  3   player_of_match   193096 non-null  object
#  4   venue             193468 non-null  object
#  5   neutral_venue     193468 non-null  int64
#  6   team1             193468 non-null  object
#  7   team2             193468 non-null  object
#  8   toss_winner       193468 non-null  object
#  9   toss_decision     193468 non-null  object
#  10  winner            193096 non-null  object
#  11  result            193096 non-null  object
#  12  result_margin     189871 non-null  float64
#  13  eliminator        193096 non-null  object
#  14  method            3208 non-null    object
#  15  umpire1           193468 non-null  object
# ...

# %%
ans2.dtypes
# Out:
# id                    int64
# city                 object
# date                 object
# player_of_match      object
# venue                object
# neutral_venue         int64
# team1                object
# team2                object
# toss_winner          object
# toss_decision        object
# winner               object
# result               object
# result_margin       float64
# eliminator           object
# method               object
# umpire1              object
# umpire2              object
# inning                int64
# over                  int64
# ball                  int64
# batsman              object
# non_striker          object
# bowler               object
# batsman_runs          int64
# extra_runs            int64
# total_runs            int64
# non_boundary          int64
# is_wicket             int64
# dismissal_kind       object
# player_dismissed     object
# fielder              object
# extras_type          object
# batting_team         object
# ...

# %%
ans2.result_margin = ans2.result_margin.astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/zh/kwjdblls3rb1w53rr2n9xd940000gn/T/ipykernel_6276/3898556350.py in <module>
# ----> 1 ans2.result_margin = ans2.result_margin.astype(int)
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %% [markdown]
# All the columns have the correct Datatype.

# %%
index = pd.Index(range(1, 193469, 1))
ans2 = ans2.set_index(index)

# %%
ans2
# Out:
#              id       city        date player_of_match  \
# 1        335982  Bangalore  2008-04-18     BB McCullum
# 2        335982  Bangalore  2008-04-18     BB McCullum
# 3        335982  Bangalore  2008-04-18     BB McCullum
# 4        335982  Bangalore  2008-04-18     BB McCullum
# 5        335982  Bangalore  2008-04-18     BB McCullum
# ...         ...        ...         ...             ...
# 193464  1237181      Dubai  2020-11-10        TA Boult
# 193465  1237181      Dubai  2020-11-10        TA Boult
# 193466  1237181      Dubai  2020-11-10        TA Boult
# 193467  1237181      Dubai  2020-11-10        TA Boult
# 193468  1237181      Dubai  2020-11-10        TA Boult
#
#                                       venue  neutral_venue  \
# 1                     M Chinnaswamy Stadium              0
# 2                     M Chinnaswamy Stadium              0
# 3                     M Chinnaswamy Stadium              0
# 4                     M Chinnaswamy Stadium              0
# ...

# %%
import seaborn as sns
sns.boxplot(ans2['batsman_runs'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/zh/kwjdblls3rb1w53rr2n9xd940000gn/T/ipykernel_6276/2769116921.py in <module>
# ----> 1 import seaborn as sns
#       2 sns.boxplot(ans2['batsman_runs'])
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
sns.boxplot(ans2['total_runs'])

# %%
ans2.groupby(ans2.date.dt.year)['sales'].sum()

# %%
gk.first()
